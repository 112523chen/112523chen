# %% [markdown]
# <a href="https://colab.research.google.com/github/112523chen/112523chen/blob/master/Day_10/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Day 10 Objectives:
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
# Basic packages
import pandas as pd 
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

root = Path('../content/')
input_path = root / 'input/' 
ouput_path = root / 'output/'
source_path = root / 'source/'

def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])
    
    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history
  
def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split() 
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1] 
    return " ".join(clean_words) 

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)
    
    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }
    
    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u 
! mkdir input/ 
! mv Tweets.csv input/

df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))  
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)

reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 219MB/s]
# mkdir: cannot create directory ‘input/’: File exists
# Epoch 1/20
# 24/24 [==============================] - 2s 59ms/step - loss: 0.8794 - accuracy: 0.6114 - val_loss: 0.7237 - val_accuracy: 0.6563
# Epoch 2/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6472 - accuracy: 0.7274 - val_loss: 0.5959 - val_accuracy: 0.7959
# Epoch 3/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.5064 - accuracy: 0.8189 - val_loss: 0.5170 - val_accuracy: 0.8065
# Epoch 4/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.4112 - accuracy: 0.8561 - val_loss: 0.4925 - val_accuracy: 0.8080
# Epoch 5/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.3468 - accuracy: 0.8786 - val_loss: 0.4946 - val_accuracy: 0.8073
# Epoch 6/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.2962 - accuracy: 0.8981 - val_loss: 0.5074 - val_accuracy: 0.8050
# Epoch 7/20
# 24/24 [==============================] - 1s 63ms/step - loss: 0.2534 - accuracy: 0.9131 - val_loss: 0.5342 - val_accuracy: 0.7944
# Epoch 8/20
# 24/24 [==============================] - 2s 88ms/step - loss: 0.2197 - accuracy: 0.9252 - val_loss: 0.5535 - val_accuracy: 0.8027
# Epoch 9/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.1905 - accuracy: 0.9381 - val_loss: 0.5730 - val_accuracy: 0.7989
# Epoch 10/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.1649 - accuracy: 0.9470 - val_loss: 0.6101 - val_accuracy: 0.7982
# Epoch 11/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.1440 - accuracy: 0.9533 - val_loss: 0.6412 - val_accuracy: 0.8058
# Epoch 12/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.1248 - accuracy: 0.9610 - val_loss: 0.6710 - val_accuracy: 0.7891
# Epoch 13/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.1098 - accuracy: 0.9660 - val_loss: 0.7048 - val_accuracy: 0.8012
# Epoch 14/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0956 - accuracy: 0.9720 - val_loss: 0.7321 - val_accuracy: 0.7883
# Epoch 15/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0853 - accuracy: 0.9745 - val_loss: 0.7640 - val_accuracy: 0.7883
# Epoch 16/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0749 - accuracy: 0.9777 - val_loss: 0.7980 - val_accuracy: 0.7868
# Epoch 17/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0673 - accuracy: 0.9795 - val_loss: 0.8326 - val_accuracy: 0.7944
# Epoch 18/20
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0601 - accuracy: 0.9826 - val_loss: 0.8625 - val_accuracy: 0.7898
# Epoch 19/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0541 - accuracy: 0.9843 - val_loss: 0.9087 - val_accuracy: 0.7944
# Epoch 20/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0496 - accuracy: 0.9860 - val_loss: 0.9333 - val_accuracy: 0.7921
# Minimum validation loss reached in epoch 4
# Epoch 1/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.9919 - accuracy: 0.6106 - val_loss: 0.9012 - val_accuracy: 0.6373
# Epoch 2/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.8440 - accuracy: 0.6495 - val_loss: 0.7951 - val_accuracy: 0.6571
# Epoch 3/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.7466 - accuracy: 0.6800 - val_loss: 0.7205 - val_accuracy: 0.6980
# Epoch 4/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.6733 - accuracy: 0.7202 - val_loss: 0.6676 - val_accuracy: 0.7291
# Epoch 5/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.6148 - accuracy: 0.7609 - val_loss: 0.6262 - val_accuracy: 0.7572
# Epoch 6/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.5667 - accuracy: 0.7922 - val_loss: 0.5934 - val_accuracy: 0.7845
# Epoch 7/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.5256 - accuracy: 0.8168 - val_loss: 0.5674 - val_accuracy: 0.8005
# Epoch 8/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.4899 - accuracy: 0.8381 - val_loss: 0.5460 - val_accuracy: 0.8012
# Epoch 9/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.4590 - accuracy: 0.8505 - val_loss: 0.5291 - val_accuracy: 0.8080
# Epoch 10/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.4319 - accuracy: 0.8614 - val_loss: 0.5158 - val_accuracy: 0.8088
# Epoch 11/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.4081 - accuracy: 0.8678 - val_loss: 0.5064 - val_accuracy: 0.8073
# Epoch 12/20
# 24/24 [==============================] - 1s 44ms/step - loss: 0.3870 - accuracy: 0.8745 - val_loss: 0.4979 - val_accuracy: 0.8134
# Epoch 13/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.3681 - accuracy: 0.8807 - val_loss: 0.4923 - val_accuracy: 0.8088
# Epoch 14/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.3511 - accuracy: 0.8838 - val_loss: 0.4896 - val_accuracy: 0.8126
# Epoch 15/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.3358 - accuracy: 0.8894 - val_loss: 0.4864 - val_accuracy: 0.8088
# Epoch 16/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.3215 - accuracy: 0.8948 - val_loss: 0.4866 - val_accuracy: 0.8080
# Epoch 17/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.3090 - accuracy: 0.8990 - val_loss: 0.4859 - val_accuracy: 0.8073
# Epoch 18/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.2972 - accuracy: 0.9017 - val_loss: 0.4867 - val_accuracy: 0.8058
# Epoch 19/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.2863 - accuracy: 0.9061 - val_loss: 0.4889 - val_accuracy: 0.8027
# Epoch 20/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.2760 - accuracy: 0.9100 - val_loss: 0.4908 - val_accuracy: 0.8058
# Minimum validation loss reached in epoch 17

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                640064
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 63ms/step - loss: 1.0600 - accuracy: 0.6782 - val_loss: 0.7511 - val_accuracy: 0.7511
# Epoch 2/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.5614 - accuracy: 0.8148 - val_loss: 0.6438 - val_accuracy: 0.7868
# Epoch 3/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.4362 - accuracy: 0.8697 - val_loss: 0.6357 - val_accuracy: 0.7974
# Epoch 4/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.3694 - accuracy: 0.9014 - val_loss: 0.6182 - val_accuracy: 0.7997
# Epoch 5/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.3230 - accuracy: 0.9237 - val_loss: 0.6310 - val_accuracy: 0.8027
# Epoch 6/20
# 24/24 [==============================] - 2s 84ms/step - loss: 0.2914 - accuracy: 0.9364 - val_loss: 0.6315 - val_accuracy: 0.8096
# Epoch 7/20
# 24/24 [==============================] - 2s 99ms/step - loss: 0.2657 - accuracy: 0.9474 - val_loss: 0.6418 - val_accuracy: 0.8103
# Epoch 8/20
# 24/24 [==============================] - 2s 86ms/step - loss: 0.2474 - accuracy: 0.9577 - val_loss: 0.6680 - val_accuracy: 0.7982
# Epoch 9/20
# 24/24 [==============================] - 2s 100ms/step - loss: 0.2315 - accuracy: 0.9633 - val_loss: 0.6658 - val_accuracy: 0.8058
# Epoch 10/20
# 24/24 [==============================] - 2s 84ms/step - loss: 0.2207 - accuracy: 0.9681 - val_loss: 0.7094 - val_accuracy: 0.7997
# Epoch 11/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.2116 - accuracy: 0.9730 - val_loss: 0.6945 - val_accuracy: 0.8118
# Epoch 12/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2033 - accuracy: 0.9747 - val_loss: 0.7129 - val_accuracy: 0.7860
# Epoch 13/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.1957 - accuracy: 0.9783 - val_loss: 0.6994 - val_accuracy: 0.8073
# Epoch 14/20
# 24/24 [==============================] - 2s 90ms/step - loss: 0.1886 - accuracy: 0.9784 - val_loss: 0.7475 - val_accuracy: 0.7906
# Epoch 15/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.1847 - accuracy: 0.9806 - val_loss: 0.7423 - val_accuracy: 0.7967
# Epoch 16/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.1792 - accuracy: 0.9831 - val_loss: 0.7180 - val_accuracy: 0.8035
# Epoch 17/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.1754 - accuracy: 0.9839 - val_loss: 0.7220 - val_accuracy: 0.7853
# Epoch 18/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.1706 - accuracy: 0.9850 - val_loss: 0.7409 - val_accuracy: 0.8027
# Epoch 19/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.1680 - accuracy: 0.9842 - val_loss: 0.7316 - val_accuracy: 0.8027
# Epoch 20/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.1636 - accuracy: 0.9866 - val_loss: 0.7428 - val_accuracy: 0.7914
# Minimum validation loss reached in epoch 4

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 1

# %%
weights = [-5, 4, -3, 2, 1]
from numpy.linalg import norm
def l1_norm(weights):
    # Enter your code here
    reg = norm(weights, 1)
    return reg

print(l1_norm(weights))
# Out:
# 15.0

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 2

# %%
weights = [-5, 4, -3, 2, 1]

def l2_norm(weights):
    # Enter your code here
    reg = norm(weights)
    return reg

print(l2_norm(weights))
# Out:
# 7.416198487095663

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 73ms/step - loss: 0.9275 - accuracy: 0.5979 - val_loss: 0.7687 - val_accuracy: 0.6305
# Epoch 2/20
# 24/24 [==============================] - 2s 98ms/step - loss: 0.7426 - accuracy: 0.6528 - val_loss: 0.6625 - val_accuracy: 0.7102
# Epoch 3/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.6424 - accuracy: 0.7358 - val_loss: 0.5847 - val_accuracy: 0.7815
# Epoch 4/20
# 24/24 [==============================] - 2s 75ms/step - loss: 0.5547 - accuracy: 0.7970 - val_loss: 0.5361 - val_accuracy: 0.7914
# Epoch 5/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.4897 - accuracy: 0.8247 - val_loss: 0.5118 - val_accuracy: 0.8058
# Epoch 6/20
# 24/24 [==============================] - 2s 92ms/step - loss: 0.4389 - accuracy: 0.8447 - val_loss: 0.5021 - val_accuracy: 0.8187
# Epoch 7/20
# 24/24 [==============================] - 3s 118ms/step - loss: 0.3998 - accuracy: 0.8571 - val_loss: 0.4948 - val_accuracy: 0.8020
# Epoch 8/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.3655 - accuracy: 0.8706 - val_loss: 0.4998 - val_accuracy: 0.8073
# Epoch 9/20
# 24/24 [==============================] - 2s 93ms/step - loss: 0.3310 - accuracy: 0.8842 - val_loss: 0.5125 - val_accuracy: 0.8103
# Epoch 10/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.3085 - accuracy: 0.8949 - val_loss: 0.5245 - val_accuracy: 0.8096
# Epoch 11/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.2829 - accuracy: 0.9029 - val_loss: 0.5473 - val_accuracy: 0.8080
# Epoch 12/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.2596 - accuracy: 0.9120 - val_loss: 0.5554 - val_accuracy: 0.8134
# Epoch 13/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.2414 - accuracy: 0.9168 - val_loss: 0.5687 - val_accuracy: 0.8103
# Epoch 14/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.2204 - accuracy: 0.9270 - val_loss: 0.5927 - val_accuracy: 0.8065
# Epoch 15/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2040 - accuracy: 0.9310 - val_loss: 0.6130 - val_accuracy: 0.8027
# Epoch 16/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.1955 - accuracy: 0.9331 - val_loss: 0.6289 - val_accuracy: 0.8027
# Epoch 17/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.1779 - accuracy: 0.9404 - val_loss: 0.6568 - val_accuracy: 0.8050
# Epoch 18/20
# 24/24 [==============================] - 2s 95ms/step - loss: 0.1676 - accuracy: 0.9454 - val_loss: 0.6849 - val_accuracy: 0.7997
# Epoch 19/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.1571 - accuracy: 0.9475 - val_loss: 0.7052 - val_accuracy: 0.7997
# Epoch 20/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.1475 - accuracy: 0.9508 - val_loss: 0.7293 - val_accuracy: 0.8058
# Minimum validation loss reached in epoch 7

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3)
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 10s 364ms/step - loss: 1.4198 - accuracy: 0.1693 - val_loss: 1.0757 - val_accuracy: 0.1047
# Epoch 2/20
# 24/24 [==============================] - 10s 422ms/step - loss: 2.9481 - accuracy: 0.3248 - val_loss: 1.1948 - val_accuracy: 0.6282
# Epoch 3/20
# 24/24 [==============================] - 10s 400ms/step - loss: 1.1386 - accuracy: 0.6311 - val_loss: 1.1888 - val_accuracy: 0.6791
# Epoch 4/20
# 24/24 [==============================] - 8s 346ms/step - loss: 3.7172 - accuracy: 0.6616 - val_loss: 1.3454 - val_accuracy: 0.2663
# Epoch 5/20
# 24/24 [==============================] - 9s 359ms/step - loss: 1.1264 - accuracy: 0.1595 - val_loss: 1.1440 - val_accuracy: 0.0835
# Epoch 6/20
# 24/24 [==============================] - 10s 413ms/step - loss: 6.3315 - accuracy: 0.0754 - val_loss: 1.6599 - val_accuracy: 0.0888
# Epoch 7/20
# 24/24 [==============================] - 10s 418ms/step - loss: 1.1962 - accuracy: 0.5267 - val_loss: 1.0859 - val_accuracy: 0.6988
# Epoch 8/20
# 24/24 [==============================] - 11s 464ms/step - loss: 7.2224 - accuracy: 0.7360 - val_loss: 9.0749 - val_accuracy: 0.7284
# Epoch 9/20
# 24/24 [==============================] - 11s 439ms/step - loss: 7.7628 - accuracy: 0.7547 - val_loss: 10.6977 - val_accuracy: 0.6973
# Epoch 10/20
# 24/24 [==============================] - 9s 359ms/step - loss: 5.5800 - accuracy: 0.5145 - val_loss: 0.9846 - val_accuracy: 0.1024
# Epoch 11/20
# 24/24 [==============================] - 9s 384ms/step - loss: 4.4684 - accuracy: 0.2557 - val_loss: 3.5738 - val_accuracy: 0.6275
# Epoch 12/20
# 24/24 [==============================] - 9s 372ms/step - loss: 6.7975 - accuracy: 0.6167 - val_loss: 10.9085 - val_accuracy: 0.6457
# Epoch 13/20
# 24/24 [==============================] - 11s 473ms/step - loss: 9.9742 - accuracy: 0.6374 - val_loss: 10.9999 - val_accuracy: 0.6282
# Epoch 14/20
# 24/24 [==============================] - 9s 350ms/step - loss: 7.9321 - accuracy: 0.6366 - val_loss: 4.1444 - val_accuracy: 0.6753
# Epoch 15/20
# 24/24 [==============================] - 8s 351ms/step - loss: 8.4756 - accuracy: 0.6511 - val_loss: 4.6533 - val_accuracy: 0.6282
# Epoch 16/20
# 24/24 [==============================] - 8s 350ms/step - loss: 5.8225 - accuracy: 0.6273 - val_loss: 3.4734 - val_accuracy: 0.6282
# Epoch 17/20
# 24/24 [==============================] - 7s 303ms/step - loss: 7.8280 - accuracy: 0.6300 - val_loss: 10.6900 - val_accuracy: 0.6282
# Epoch 18/20
# 24/24 [==============================] - 9s 360ms/step - loss: 7.8480 - accuracy: 0.6313 - val_loss: 10.5379 - val_accuracy: 0.6282
# Epoch 19/20
# 24/24 [==============================] - 7s 297ms/step - loss: 8.5385 - accuracy: 0.6280 - val_loss: 10.3137 - val_accuracy: 0.6282
# Epoch 20/20
# 24/24 [==============================] - 8s 352ms/step - loss: 7.3521 - accuracy: 0.6285 - val_loss: 4.9774 - val_accuracy: 0.6282
# Minimum validation loss reached in epoch 10

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?

# %% [markdown]
# ### Answer 3
#
# It makes sense to add L2 reularization and Dropout when you have overfitting which in the perfect world would reduce loos resulting in better model. In this case it seems to not work.

# %% [markdown]
# #Training on the full train data and evaluation on test dataAt first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/4
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1385 - accuracy: 0.9662
# Epoch 2/4
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0932 - accuracy: 0.9763
# Epoch 3/4
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0733 - accuracy: 0.9789
# Epoch 4/4
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0605 - accuracy: 0.9836
# 46/46 [==============================] - 0s 4ms/step - loss: 1.0382 - accuracy: 0.7671
#
# Test accuracy: 76.71%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/17
# 26/26 [==============================] - 2s 60ms/step - loss: 0.2890 - accuracy: 0.9020
# Epoch 2/17
# 26/26 [==============================] - 1s 52ms/step - loss: 0.2776 - accuracy: 0.9075
# Epoch 3/17
# 26/26 [==============================] - 2s 81ms/step - loss: 0.2674 - accuracy: 0.9111
# Epoch 4/17
# 26/26 [==============================] - 2s 62ms/step - loss: 0.2576 - accuracy: 0.9151
# Epoch 5/17
# 26/26 [==============================] - 1s 43ms/step - loss: 0.2484 - accuracy: 0.9181
# Epoch 6/17
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2401 - accuracy: 0.9209
# Epoch 7/17
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2323 - accuracy: 0.9234
# Epoch 8/17
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2247 - accuracy: 0.9262
# Epoch 9/17
# 26/26 [==============================] - 1s 28ms/step - loss: 0.2175 - accuracy: 0.9296
# Epoch 10/17
# 26/26 [==============================] - 1s 28ms/step - loss: 0.2106 - accuracy: 0.9325
# Epoch 11/17
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2040 - accuracy: 0.9340
# Epoch 12/17
# 26/26 [==============================] - 1s 38ms/step - loss: 0.1977 - accuracy: 0.9372
# Epoch 13/17
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1917 - accuracy: 0.9398
# Epoch 14/17
# 26/26 [==============================] - 1s 28ms/step - loss: 0.1859 - accuracy: 0.9425
# Epoch 15/17
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1804 - accuracy: 0.9438
# Epoch 16/17
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1750 - accuracy: 0.9461
# Epoch 17/17
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1700 - accuracy: 0.9468
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6519 - accuracy: 0.7746
#
# Test accuracy: 77.46%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/4
# 26/26 [==============================] - 2s 69ms/step - loss: 1.0159 - accuracy: 0.6868
# Epoch 2/4
# 26/26 [==============================] - 1s 48ms/step - loss: 0.4769 - accuracy: 0.8521
# Epoch 3/4
# 26/26 [==============================] - 1s 47ms/step - loss: 0.3556 - accuracy: 0.9035
# Epoch 4/4
# 26/26 [==============================] - 1s 46ms/step - loss: 0.2891 - accuracy: 0.9349
# 46/46 [==============================] - 0s 4ms/step - loss: 0.7149 - accuracy: 0.7869
#
# Test accuracy: 78.69%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/7
# 26/26 [==============================] - 3s 94ms/step - loss: 1.2096 - accuracy: 0.6501
# Epoch 2/7
# 26/26 [==============================] - 1s 52ms/step - loss: 0.7443 - accuracy: 0.7206
# Epoch 3/7
# 26/26 [==============================] - 1s 53ms/step - loss: 0.6104 - accuracy: 0.7656
# Epoch 4/7
# 26/26 [==============================] - 1s 51ms/step - loss: 0.5247 - accuracy: 0.8012
# Epoch 5/7
# 26/26 [==============================] - 1s 50ms/step - loss: 0.4599 - accuracy: 0.8270
# Epoch 6/7
# 26/26 [==============================] - 1s 51ms/step - loss: 0.4106 - accuracy: 0.8493
# Epoch 7/7
# 26/26 [==============================] - 1s 50ms/step - loss: 0.3734 - accuracy: 0.8654
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5969 - accuracy: 0.7684
#
# Test accuracy: 76.84%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2) #(𝐲−𝐱𝑊)2+λ||𝑊||22
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus question: Plot the same for L1 regularization

# %% [markdown]
# ### Answer

# %%
cost = lambda w: np.mean((w[0] + w[1]*x - y)**2) #(𝐲−𝐱𝑊)2+λ||𝑊||
l1_penalty = lambda w: np.dot(w,w)
cost_plus_l1 = lambda w: cost(w) + 5*l1_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?
#
# \<*Type your answer here*\>

# %% [markdown]
# # **Upload this Day 9 Colab Notebook to your Github repository under "Day 9" folder. Also add your *Reflection* on today's learning in README.md**
